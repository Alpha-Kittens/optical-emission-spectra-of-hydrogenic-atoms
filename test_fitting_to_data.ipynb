# %%
import import_ipynb
from lorentzian_fit import fit_to_lorentzian
from lorentzian_fit import show_results
from data import data_loader
# Out:
# importing Jupyter notebook from lorentzian_fit.ipynb

# %%
data = data_loader.read_data('data/day_1/calibration_scan_8_3622_3632')
result = fit_to_lorentzian(data)
show_results(result)
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 501
#     # variables        = 3
#     chi-square         = 1.2834e+11
#     reduced chi-square = 2.5771e+08
#     Akaike info crit   = 9706.02465
#     Bayesian info crit = 9718.67446
# [[Variables]]
#     amp:    263861.334 +/- 3722.53398 (1.41%) (init = 363050)
#     cen:    3627.22601 +/- 0.00301776 (0.00%) (init = 3627.26)
#     scale:  0.21397454 +/- 0.00426839 (1.99%) (init = 0.5)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, scale) =  0.707
