# %%
import import_ipynb
from lorentzian_fit import fit_to_lorentzian
from lorentzian_fit import show_results
from data import data_loader

# %%
data = data_loader.read_data('data/day_1/calibration_scan_10_3627_3627.5')
result = fit_to_lorentzian(data)
lorentzian_fit.show_results(result)
# Out:
# ['1.000', '3627.000', '357920.000\n']
# ['2.000', '3627.003', '354350.000\n']
# ['3.000', '3627.005', '352050.000\n']
# ['4.000', '3627.008', '350950.000\n']
# ['5.000', '3627.010', '346440.000\n']
# ['6.000', '3627.012', '345950.000\n']
# ['7.000', '3627.015', '345060.000\n']
# ['8.000', '3627.017', '352170.000\n']
# ['9.000', '3627.020', '344110.000\n']
# ['10.000', '3627.023', '348280.000\n']
# ['11.000', '3627.025', '343980.000\n']
# ['12.000', '3627.028', '338060.000\n']
# ['13.000', '3627.030', '343080.000\n']
# ['14.000', '3627.032', '339630.000\n']
# ['15.000', '3627.035', '337580.000\n']
# ['16.000', '3627.037', '348220.000\n']
# ['17.000', '3627.040', '349440.000\n']
# ['18.000', '3627.043', '348750.000\n']
# ['19.000', '3627.045', '337060.000\n']
# ['20.000', '3627.048', '343660.000\n']
# ['21.000', '3627.050', '345480.000\n']
# ['22.000', '3627.052', '340460.000\n']
# ['23.000', '3627.055', '338060.000\n']
# ['24.000', '3627.057', '348160.000\n']
# ...
